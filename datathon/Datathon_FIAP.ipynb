# %% [markdown]
# Datathon - Passos mágicos

# %% [markdown]
# # Análise exploratória de dados

# %%
# Importação de bibliotecas básicas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Informações básicas e tramentos iniciais

# %%
# Trazendo a base fornecida pelas ONG

df = pd.read_csv("/content/PEDE_PASSOS_DATASET_FIAP.csv", sep=";")
df_bkp = df.copy()

df.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 1                           NaN  ALUNO-2              NaN          NaN
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020          INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não           7.883752                  B
# 1             NaN               NaN                NaN                NaN
# 2              3H               Não  7.856389666666666                  B
# 3              1D               Não           5.076252                  D
# 4              2M               Não           8.077085                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  ...  \
# 0   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
# 1        NaN                                                NaN  ...
# 2   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
# 3    Quartzo  Ponto a melhorar em 2021: Melhorar a sua entre...  ...
# 4   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
#
#    IPP_2022           REC_AVA_1_2022         REC_AVA_2_2022  \
# 0       NaN                      NaN                    NaN
# 1  5.625000  Mantido na Fase + Bolsa  Mantido na Fase atual
# 2       NaN                      NaN                    NaN
# 3  6.250000        Promovido de Fase  Mantido na Fase atual
# 4  6.458333    Mantido na Fase atual      Promovido de Fase
#
#           REC_AVA_3_2022 REC_AVA_4_2022 INDICADO_BOLSA_2022 PONTO_VIRADA_2022  \
# 0                    NaN            NaN                 NaN               NaN
# 1                    NaN            NaN                 Sim               Não
# 2                    NaN            NaN                 NaN               NaN
# 3      Promovido de Fase            NaN                 Não               Não
# 4  Mantido na Fase atual            NaN                 Não               Não
#
#    IPV_2022 IAN_2022      NIVEL_IDEAL_2022
# 0       NaN      NaN                   NaN
# 1  7.916665      5.0  Fase 2 (5º e 6º ano)
# 2       NaN      NaN                   NaN
# 3  8.055553      5.0  Fase 3 (7º e 8º ano)
# 4  7.833337      5.0  Fase 3 (7º e 8º ano)
#
# [5 rows x 69 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  728 non-null    object
#  1   NOME                           1349 non-null   object
#  2   IDADE_ALUNO_2020               728 non-null    object
#  3   ANOS_PM_2020                   728 non-null    object
#  4   FASE_TURMA_2020                728 non-null    object
#  5   PONTO_VIRADA_2020              702 non-null    object
#  6   INDE_2020                      728 non-null    object
#  7   INDE_CONCEITO_2020             728 non-null    object
#  8   PEDRA_2020                     728 non-null    object
#  9   DESTAQUE_IEG_2020              728 non-null    object
#  10  DESTAQUE_IDA_2020              728 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       728 non-null    object
#  13  IEG_2020                       728 non-null    object
#  14  IPS_2020                       728 non-null    object
#  15  IDA_2020                       728 non-null    object
#  16  IPP_2020                       728 non-null    object
#  17  IPV_2020                       728 non-null    object
#  18  IAN_2020                       728 non-null    object
#  19  FASE_2021                      686 non-null    float64
#  20  TURMA_2021                     686 non-null    object
#  21  INSTITUICAO_ENSINO_ALUNO_2021  686 non-null    object
#  22  SINALIZADOR_INGRESSANTE_2021   686 non-null    object
#  23  PEDRA_2021                     686 non-null    object
#  24  INDE_2021                      686 non-null    object
#  25  IAA_2021                       686 non-null    float64
#  26  IEG_2021                       686 non-null    float64
#  27  IPS_2021                       686 non-null    float64
#  28  IDA_2021                       686 non-null    float64
#  29  IPP_2021                       686 non-null    float64
#  30  REC_EQUIPE_1_2021              686 non-null    object
#  31  REC_EQUIPE_2_2021              686 non-null    object
#  32  REC_EQUIPE_3_2021              686 non-null    object
#  33  REC_EQUIPE_4_2021              686 non-null    object
#  34  PONTO_VIRADA_2021              686 non-null    object
#  35  IPV_2021                       686 non-null    float64
#  36  IAN_2021                       686 non-null    float64
#  37  NIVEL_IDEAL_2021               686 non-null    object
#  38  DEFASAGEM_2021                 686 non-null    float64
#  39  FASE_2022                      862 non-null    float64
#  40  TURMA_2022                     862 non-null    object
#  41  ANO_INGRESSO_2022              862 non-null    float64
#  42  BOLSISTA_2022                  862 non-null    object
#  43  INDE_2022                      862 non-null    float64
#  44  CG_2022                        862 non-null    float64
#  45  CF_2022                        862 non-null    float64
#  46  CT_2022                        862 non-null    float64
#  47  PEDRA_2022                     862 non-null    object
#  48  DESTAQUE_IEG_2022              862 non-null    object
#  49  DESTAQUE_IDA_2022              862 non-null    object
#  50  DESTAQUE_IPV_2022              862 non-null    object
#  51  IAA_2022                       862 non-null    float64
#  52  IEG_2022                       862 non-null    float64
#  53  IPS_2022                       862 non-null    float64
#  54  IDA_2022                       862 non-null    float64
#  55  NOTA_PORT_2022                 860 non-null    float64
#  56  NOTA_MAT_2022                  860 non-null    float64
#  57  NOTA_ING_2022                  285 non-null    float64
#  58  QTD_AVAL_2022                  862 non-null    float64
#  59  IPP_2022                       862 non-null    float64
#  60  REC_AVA_1_2022                 862 non-null    object
#  61  REC_AVA_2_2022                 862 non-null    object
#  62  REC_AVA_3_2022                 626 non-null    object
#  63  REC_AVA_4_2022                 285 non-null    object
#  64  INDICADO_BOLSA_2022            862 non-null    object
#  65  PONTO_VIRADA_2022              862 non-null    object
#  66  IPV_2022                       862 non-null    float64
#  67  IAN_2022                       862 non-null    float64
#  68  NIVEL_IDEAL_2022               862 non-null    object
# dtypes: float64(26), object(43)
# memory usage: 727.3+ KB

# %%
# Colunas nulas no dataset
df.isnull().sum()
# Out:
# INSTITUICAO_ENSINO_ALUNO_2020    621
# NOME                               0
# IDADE_ALUNO_2020                 621
# ANOS_PM_2020                     621
# FASE_TURMA_2020                  621
#                                 ...
# INDICADO_BOLSA_2022              487
# PONTO_VIRADA_2022                487
# IPV_2022                         487
# IAN_2022                         487
# NIVEL_IDEAL_2022                 487
# Length: 69, dtype: int64

# %%
df.describe().T.round(2)
# Out:
#                    count     mean     std      min      25%      50%      75%  \
# FASE_2021          686.0     2.28    1.80     0.00     1.00     2.00     3.00
# IAA_2021           686.0     8.15    2.19     0.00     7.90     8.80     9.50
# IEG_2021           686.0     6.82    2.46     0.00     5.30     7.20     8.80
# IPS_2021           686.0     6.84    1.46     0.00     6.90     7.50     7.50
# IDA_2021           686.0     5.43    2.14     0.00     4.10     5.85     6.90
# IPP_2021           686.0     7.58    1.07     0.00     7.30     7.70     8.10
# IPV_2021           686.0     7.41    1.63     0.00     6.60     7.70     8.60
# IAN_2021           686.0     6.90    2.48     2.50     5.00     5.00    10.00
# DEFASAGEM_2021     686.0    -0.75    0.79    -4.00    -1.00    -1.00     0.00
# FASE_2022          862.0     2.11    1.80     0.00     1.00     2.00     3.00
# ANO_INGRESSO_2022  862.0  2020.50    1.79  2016.00  2019.00  2021.00  2022.00
# INDE_2022          862.0     7.03    1.03     3.03     6.47     7.19     7.75
# CG_2022            862.0   431.50  248.98     1.00   216.25   431.50   646.75
# CF_2022            862.0    75.40   52.31     1.00    30.00    66.50   118.00
# CT_2022            862.0     6.62    3.99     1.00     3.00     6.00     9.75
# IAA_2022           862.0     8.26    2.08     0.00     7.92     8.75     9.50
# IEG_2022           862.0     7.88    1.65     0.00     7.00     8.31     9.10
# IPS_2022           862.0     6.90    1.07     2.50     6.25     7.50     7.50
# IDA_2022           862.0     6.07    2.06     0.00     4.75     6.33     7.58
# NOTA_PORT_2022     860.0     5.80    2.42     0.00     4.32     6.00     7.83
# NOTA_MAT_2022      860.0     6.31    2.09     0.00     5.17     6.65     7.83
# NOTA_ING_2022      285.0     5.84    2.99     0.00     3.50     6.27     8.50
# QTD_AVAL_2022      862.0     3.06    0.78     2.00     2.00     3.00     4.00
# IPP_2022           862.0     6.30    1.14     0.00     5.62     6.25     7.03
# IPV_2022           862.0     7.25    1.10     2.50     6.72     7.33     7.92
# IAN_2022           862.0     6.42    2.39     2.50     5.00     5.00    10.00
#
#                        max
# FASE_2021             7.00
# IAA_2021             10.00
# IEG_2021             10.00
# IPS_2021              8.80
# IDA_2021              9.50
# IPP_2021             10.00
# IPV_2021             10.00
# IAN_2021             10.00
# DEFASAGEM_2021        3.00
# FASE_2022             7.00
# ANO_INGRESSO_2022  2022.00
# INDE_2022             9.44
# CG_2022             862.00
# CF_2022             192.00
# CT_2022              18.00
# IAA_2022             10.00
# IEG_2022             10.00
# IPS_2022             10.00
# IDA_2022              9.92
# NOTA_PORT_2022       10.00
# NOTA_MAT_2022        10.00
# NOTA_ING_2022        10.00
# QTD_AVAL_2022         4.00
# IPP_2022              9.22
# IPV_2022             10.00
# IAN_2022             10.00

# %%
# Renomear colunas
df = df.rename(columns={
  'NOME':'nome',
  'FASE_TURMA_2020':'fase_e_turma_em_2020',
  'FASE_2021':'fase_em_2021',
  'FASE_2022':'fase_em_2022',
  'ANOS_PM_2020':'anos_na_PM_em_2020'})

# %%
# Filtra as linhas onde 'anos_na_PM_em_2020' é igual a 'D971', possível erro
df[df['anos_na_PM_em_2020'] == 'D971']
# Out:
#      INSTITUICAO_ENSINO_ALUNO_2020        nome IDADE_ALUNO_2020  \
# 1258                          V202  ALUNO-1259             D108
#
#      anos_na_PM_em_2020 fase_e_turma_em_2020 PONTO_VIRADA_2020 INDE_2020  \
# 1258               D971                 D207             D9600      D980
#
#      INDE_CONCEITO_2020 PEDRA_2020 DESTAQUE_IEG_2020  ... IPP_2022  \
# 1258            D9891/2   D9891/2A              D301  ...      NaN
#
#      REC_AVA_1_2022 REC_AVA_2_2022 REC_AVA_3_2022 REC_AVA_4_2022  \
# 1258            NaN            NaN            NaN            NaN
#
#      INDICADO_BOLSA_2022 PONTO_VIRADA_2022 IPV_2022 IAN_2022  NIVEL_IDEAL_2022
# 1258                 NaN               NaN      NaN      NaN               NaN
#
# [1 rows x 69 columns]

# %%
# Dropando linha com possível erro

df = df.drop(df[df['anos_na_PM_em_2020'] == 'D971'].index)

# %%
# Transformando tipo de colunas
df['anos_na_PM_em_2020'] = df['anos_na_PM_em_2020'].astype(float)

# %% [markdown]
# ## Fases do aluno

# %%
  df[['nome', 'fase_e_turma_em_2020', 'fase_em_2021', 'fase_em_2022']].head()
# Out:
#       nome fase_e_turma_em_2020  fase_em_2021  fase_em_2022
# 0  ALUNO-1                   2H           2.0           NaN
# 1  ALUNO-2                  NaN           NaN           0.0
# 2  ALUNO-3                   3H           3.0           NaN
# 3  ALUNO-4                   1D           NaN           2.0
# 4  ALUNO-5                   2M           2.0           2.0

# %%
  df[['nome', 'fase_e_turma_em_2020', 'fase_em_2021', 'fase_em_2022']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1348 entries, 0 to 1348
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nome                  1348 non-null   object
#  1   fase_e_turma_em_2020  727 non-null    object
#  2   fase_em_2021          686 non-null    float64
#  3   fase_em_2022          862 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 52.7+ KB

# %%
# Extrai a parte numérica da string na coluna 'fase_e_turma_em_2020'
df['fase_em_2020'] = df['fase_e_turma_em_2020'].str.extract('(\d+)')
df['fase_em_2020'] = df['fase_em_2020'].astype(float)

# %%
  df[['nome', 'fase_em_2020', 'fase_em_2021', 'fase_em_2022']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1348 entries, 0 to 1348
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nome          1348 non-null   object
#  1   fase_em_2020  727 non-null    float64
#  2   fase_em_2021  686 non-null    float64
#  3   fase_em_2022  862 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 52.7+ KB

# %%
  df[['nome', 'fase_em_2020', 'fase_em_2021', 'fase_em_2022']].head()
# Out:
#       nome  fase_em_2020  fase_em_2021  fase_em_2022
# 0  ALUNO-1           2.0           2.0           NaN
# 1  ALUNO-2           NaN           NaN           0.0
# 2  ALUNO-3           3.0           3.0           NaN
# 3  ALUNO-4           1.0           NaN           2.0
# 4  ALUNO-5           2.0           2.0           2.0

# %% [markdown]
# ## Dimensões de temporalidade

# %%
# Cria colunas para verificar se o aluno era ou não aluno com base na inscrição de turma
df['aluno_em_2020'] = df['fase_em_2020'].notna()
df['aluno_em_2021'] = df['fase_em_2021'].notna()
df['aluno_em_2022'] = df['fase_em_2022'].notna()

df[['nome', 'aluno_em_2020', 'aluno_em_2021', 'aluno_em_2022']].head()
# Out:
#       nome  aluno_em_2020  aluno_em_2021  aluno_em_2022
# 0  ALUNO-1           True           True          False
# 1  ALUNO-2          False          False           True
# 2  ALUNO-3           True           True          False
# 3  ALUNO-4           True          False           True
# 4  ALUNO-5           True           True           True

# %%
# Histórico não disponível na base

# Inicializa as novas colunas com FALSE
df['aluno_em_2019'] = False
df['aluno_em_2018'] = False
df['aluno_em_2017'] = False
df['aluno_em_2016'] = False

# Aplica a lógica
df.loc[df['aluno_em_2020'] & (df['anos_na_PM_em_2020'] >= 1), 'aluno_em_2019'] = True
df.loc[df['aluno_em_2020'] & (df['anos_na_PM_em_2020'] >= 2), 'aluno_em_2018'] = True
df.loc[df['aluno_em_2020'] & (df['anos_na_PM_em_2020'] >= 3), 'aluno_em_2017'] = True
df.loc[df['aluno_em_2020'] & (df['anos_na_PM_em_2020'] >= 4), 'aluno_em_2016'] = True

df[['nome', 'aluno_em_2016', 'aluno_em_2017', 'aluno_em_2018', 'aluno_em_2019', 'aluno_em_2020', 'anos_na_PM_em_2020']].head()
# Out:
#       nome  aluno_em_2016  aluno_em_2017  aluno_em_2018  aluno_em_2019  \
# 0  ALUNO-1          False          False           True           True
# 1  ALUNO-2          False          False          False          False
# 2  ALUNO-3          False          False           True           True
# 3  ALUNO-4          False          False           True           True
# 4  ALUNO-5          False          False          False           True
#
#    aluno_em_2020  anos_na_PM_em_2020
# 0           True                 2.0
# 1          False                 NaN
# 2           True                 2.0
# 3           True                 2.0
# 4           True                 1.0

# %%
# Ano de entrada do aluno
def encontrar_ano_de_entrada(row):
    if row['aluno_em_2016']:
        return 2016
    elif row['aluno_em_2017']:
        return 2017
    elif row['aluno_em_2018']:
        return 2018
    elif row['aluno_em_2019']:
        return 2019
    elif row['aluno_em_2020']:
        return 2020
    elif row['aluno_em_2021']:
        return 2021
    elif row['aluno_em_2021']:
        return 2021
    elif row['aluno_em_2022']:
        return 2022
    else:
        return None  # ou um valor padrão se você souber que sempre haverá um ano de entrada

# Aplicando a função em cada linha do DataFrame
df['ano_de_entrada'] = df.apply(encontrar_ano_de_entrada, axis=1)

df[['nome', 'aluno_em_2020', 'aluno_em_2021', 'aluno_em_2022', 'ano_de_entrada', 'anos_na_PM_em_2020']].head()
# Out:
#       nome  aluno_em_2020  aluno_em_2021  aluno_em_2022  ano_de_entrada  \
# 0  ALUNO-1           True           True          False            2018
# 1  ALUNO-2          False          False           True            2022
# 2  ALUNO-3           True           True          False            2018
# 3  ALUNO-4           True          False           True            2018
# 4  ALUNO-5           True           True           True            2019
#
#    anos_na_PM_em_2020
# 0                 2.0
# 1                 NaN
# 2                 2.0
# 3                 2.0
# 4                 1.0

# %%
# Ano de saída
def encontrar_ano_de_saida(row):
    if row['aluno_em_2022']:
        return 2022
    elif row['aluno_em_2021']:
        return 2021
    elif row['aluno_em_2020']:
        return 2020
    elif row['aluno_em_2019']:
        return 2019
    elif row['aluno_em_2018']:
        return 2018
    elif row['aluno_em_2017']:
        return 2017
    elif row['aluno_em_2016']:
        return 2016
    else:
        return None  # ou um valor padrão se necessário

# Aplicando a função em cada linha do DataFrame
df['ano_de_saida'] = df.apply(encontrar_ano_de_saida, axis=1)
# Se ano for 2022, o aluno ainda é ativo
df['ano_de_saida'] = np.where(df['ano_de_saida'] == 2022, np.nan, df['ano_de_saida'])
# Criando regra boleana se é ainda ou não aluno
df['aluno_no_momento'] = df['ano_de_saida'].isna()

df[['nome', 'aluno_em_2020', 'aluno_em_2021', 'aluno_em_2022', 'ano_de_entrada', 'ano_de_saida', 'aluno_no_momento']].head()
# Out:
#       nome  aluno_em_2020  aluno_em_2021  aluno_em_2022  ano_de_entrada  \
# 0  ALUNO-1           True           True          False            2018
# 1  ALUNO-2          False          False           True            2022
# 2  ALUNO-3           True           True          False            2018
# 3  ALUNO-4           True          False           True            2018
# 4  ALUNO-5           True           True           True            2019
#
#    ano_de_saida  aluno_no_momento
# 0        2021.0             False
# 1           NaN              True
# 2        2021.0             False
# 3           NaN              True
# 4           NaN              True

# %%
# Soma das colunas booleanas para cada aluno para obter a quantidade de anos matriculados
df['anos_matriculados'] = df[['aluno_em_2020', 'aluno_em_2021', 'aluno_em_2022']].sum(axis=1)

df[['nome', 'aluno_em_2020', 'aluno_em_2021', 'aluno_em_2022', 'ano_de_entrada', 'ano_de_saida', 'aluno_no_momento', 'anos_matriculados']].head()
# Out:
#       nome  aluno_em_2020  aluno_em_2021  aluno_em_2022  ano_de_entrada  \
# 0  ALUNO-1           True           True          False            2018
# 1  ALUNO-2          False          False           True            2022
# 2  ALUNO-3           True           True          False            2018
# 3  ALUNO-4           True          False           True            2018
# 4  ALUNO-5           True           True           True            2019
#
#    ano_de_saida  aluno_no_momento  anos_matriculados
# 0        2021.0             False                  2
# 1           NaN              True                  1
# 2        2021.0             False                  2
# 3           NaN              True                  2
# 4           NaN              True                  3

# %% [markdown]
# ## Índices dos alunos

# %%
# Formatar colunas de índices
colunas_selecionadas = [
                        #2020
                        'IAN_2020',
                        'IDA_2020',
                        'IEG_2020',
                        'IAA_2020',
                        'IPS_2020',
                        'IPP_2020',
                        'IPV_2020',
                        #2021
                        'IAN_2021',
                        'IDA_2021',
                        'IEG_2021',
                        'IAA_2021',
                        'IPS_2021',
                        'IPP_2021',
                        'IPV_2021',
                        #2022
                        'IAN_2022',
                        'IDA_2022',
                        'IEG_2022',
                        'IAA_2022',
                        'IPS_2022',
                        'IPP_2022',
                        'IPV_2022']

df[colunas_selecionadas] = df[colunas_selecionadas].astype(float)
df[colunas_selecionadas] = df[colunas_selecionadas].round(1)

# %%
# Configura o Pandas para exibir todas as colunas
pd.set_option('display.max_columns', None)

df[colunas_selecionadas].head()
# Out:
#    IAN_2020  IDA_2020  IEG_2020  IAA_2020  IPS_2020  IPP_2020  IPV_2020  \
# 0      10.0       7.0       8.7       8.5       7.5       5.9       7.8
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      10.0       5.5       8.9       7.9       7.5       8.1       8.1
# 3       5.0       0.0       4.1       8.0       6.9       7.2       7.8
# 4      10.0       7.5       8.0       7.5       7.5       8.4       8.2
#
#    IAN_2021  IDA_2021  IEG_2021  IAA_2021  IPS_2021  IPP_2021  IPV_2021  \
# 0       5.0       8.8       6.3       7.5       6.9       7.7       8.1
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      10.0       5.6       6.9       7.1       6.3       7.3       7.2
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      10.0       5.4       7.5       7.4       7.5       8.5       7.4
#
#    IAN_2022  IDA_2022  IEG_2022  IAA_2022  IPS_2022  IPP_2022  IPV_2022
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       5.0       8.8       7.6      10.0       7.5       5.6       7.9
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       5.0       5.1       8.1      10.0       7.5       6.2       8.1
# 4       5.0       7.1       8.6       6.4       7.5       6.5       7.8

# %%
df[colunas_selecionadas].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1348 entries, 0 to 1348
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   IAN_2020  727 non-null    float64
#  1   IDA_2020  727 non-null    float64
#  2   IEG_2020  727 non-null    float64
#  3   IAA_2020  727 non-null    float64
#  4   IPS_2020  727 non-null    float64
#  5   IPP_2020  727 non-null    float64
#  6   IPV_2020  727 non-null    float64
#  7   IAN_2021  686 non-null    float64
#  8   IDA_2021  686 non-null    float64
#  9   IEG_2021  686 non-null    float64
#  10  IAA_2021  686 non-null    float64
#  11  IPS_2021  686 non-null    float64
#  12  IPP_2021  686 non-null    float64
#  13  IPV_2021  686 non-null    float64
#  14  IAN_2022  862 non-null    float64
#  15  IDA_2022  862 non-null    float64
#  16  IEG_2022  862 non-null    float64
#  17  IAA_2022  862 non-null    float64
#  18  IPS_2022  862 non-null    float64
#  19  IPP_2022  862 non-null    float64
#  20  IPV_2022  862 non-null    float64
# dtypes: float64(21)
# memory usage: 231.7 KB

# %%
df[colunas_selecionadas].isnull().sum()
# Out:
# IAN_2020    621
# IDA_2020    621
# IEG_2020    621
# IAA_2020    621
# IPS_2020    621
# IPP_2020    621
# IPV_2020    621
# IAN_2021    662
# IDA_2021    662
# IEG_2021    662
# IAA_2021    662
# IPS_2021    662
# IPP_2021    662
# IPV_2021    662
# IAN_2022    486
# IDA_2022    486
# IEG_2022    486
# IAA_2022    486
# IPS_2022    486
# IPP_2022    486
# IPV_2022    486
# dtype: int64

# %%
df[colunas_selecionadas].describe().T.round(2)
# Out:
#           count  mean   std  min   25%   50%   75%   max
# IAN_2020  727.0  7.43  2.56  2.5  5.00  5.00  10.0  10.0
# IDA_2020  727.0  6.32  2.96  0.0  4.70  7.00   8.7  10.0
# IEG_2020  727.0  7.68  2.38  0.0  6.60  8.50   9.5  10.0
# IAA_2020  727.0  8.37  1.73  0.0  7.95  8.80   9.2  10.0
# IPS_2020  727.0  6.74  1.37  2.5  5.60  7.50   7.5  10.0
# IPP_2020  727.0  7.07  1.99  0.0  6.95  7.50   8.1  10.0
# IPV_2020  727.0  7.24  1.77  0.0  6.90  7.60   8.1  10.0
# IAN_2021  686.0  6.90  2.48  2.5  5.00  5.00  10.0  10.0
# IDA_2021  686.0  5.43  2.14  0.0  4.10  5.85   6.9   9.5
# IEG_2021  686.0  6.82  2.46  0.0  5.30  7.20   8.8  10.0
# IAA_2021  686.0  8.15  2.19  0.0  7.90  8.80   9.5  10.0
# IPS_2021  686.0  6.84  1.46  0.0  6.90  7.50   7.5   8.8
# IPP_2021  686.0  7.58  1.07  0.0  7.30  7.70   8.1  10.0
# IPV_2021  686.0  7.41  1.63  0.0  6.60  7.70   8.6  10.0
# IAN_2022  862.0  6.42  2.39  2.5  5.00  5.00  10.0  10.0
# IDA_2022  862.0  6.07  2.06  0.0  4.80  6.30   7.6   9.9
# IEG_2022  862.0  7.88  1.65  0.0  7.00  8.30   9.1  10.0
# IAA_2022  862.0  8.26  2.08  0.0  7.90  8.80   9.5  10.0
# IPS_2022  862.0  6.90  1.07  2.5  6.20  7.50   7.5  10.0
# IPP_2022  862.0  6.29  1.14  0.0  5.60  6.20   7.0   9.2
# IPV_2022  862.0  7.25  1.10  2.5  6.70  7.30   7.9  10.0

# %%
df_indicadores = df[colunas_selecionadas].describe().T.round(2)

# %%
df_indicadores['ano'] = df_indicadores.index.to_series().str.extract('(\d{4})').astype(int)
df_indicadores.head()
# Out:
#           count  mean   std  min   25%  50%   75%   max   ano
# IAN_2020  727.0  7.43  2.56  2.5  5.00  5.0  10.0  10.0  2020
# IDA_2020  727.0  6.32  2.96  0.0  4.70  7.0   8.7  10.0  2020
# IEG_2020  727.0  7.68  2.38  0.0  6.60  8.5   9.5  10.0  2020
# IAA_2020  727.0  8.37  1.73  0.0  7.95  8.8   9.2  10.0  2020
# IPS_2020  727.0  6.74  1.37  2.5  5.60  7.5   7.5  10.0  2020

# %%
# Transforma o índice em uma coluna
df_indicadores = df_indicadores.reset_index()

# Agora o índice anterior está em uma coluna chamada 'index', você pode renomear essa coluna se desejar
df_indicadores = df_indicadores.rename(columns={'index': 'indicador'})

# %%
df_indicadores
# Out:
#    indicador  count  mean   std  min   25%   50%   75%   max   ano
# 0   IAN_2020  727.0  7.43  2.56  2.5  5.00  5.00  10.0  10.0  2020
# 1   IDA_2020  727.0  6.32  2.96  0.0  4.70  7.00   8.7  10.0  2020
# 2   IEG_2020  727.0  7.68  2.38  0.0  6.60  8.50   9.5  10.0  2020
# 3   IAA_2020  727.0  8.37  1.73  0.0  7.95  8.80   9.2  10.0  2020
# 4   IPS_2020  727.0  6.74  1.37  2.5  5.60  7.50   7.5  10.0  2020
# 5   IPP_2020  727.0  7.07  1.99  0.0  6.95  7.50   8.1  10.0  2020
# 6   IPV_2020  727.0  7.24  1.77  0.0  6.90  7.60   8.1  10.0  2020
# 7   IAN_2021  686.0  6.90  2.48  2.5  5.00  5.00  10.0  10.0  2021
# 8   IDA_2021  686.0  5.43  2.14  0.0  4.10  5.85   6.9   9.5  2021
# 9   IEG_2021  686.0  6.82  2.46  0.0  5.30  7.20   8.8  10.0  2021
# 10  IAA_2021  686.0  8.15  2.19  0.0  7.90  8.80   9.5  10.0  2021
# 11  IPS_2021  686.0  6.84  1.46  0.0  6.90  7.50   7.5   8.8  2021
# 12  IPP_2021  686.0  7.58  1.07  0.0  7.30  7.70   8.1  10.0  2021
# 13  IPV_2021  686.0  7.41  1.63  0.0  6.60  7.70   8.6  10.0  2021
# 14  IAN_2022  862.0  6.42  2.39  2.5  5.00  5.00  10.0  10.0  2022
# 15  IDA_2022  862.0  6.07  2.06  0.0  4.80  6.30   7.6   9.9  2022
# 16  IEG_2022  862.0  7.88  1.65  0.0  7.00  8.30   9.1  10.0  2022
# 17  IAA_2022  862.0  8.26  2.08  0.0  7.90  8.80   9.5  10.0  2022
# 18  IPS_2022  862.0  6.90  1.07  2.5  6.20  7.50   7.5  10.0  2022
# 19  IPP_2022  862.0  6.29  1.14  0.0  5.60  6.20   7.0   9.2  2022
# 20  IPV_2022  862.0  7.25  1.10  2.5  6.70  7.30   7.9  10.0  2022

# %%
df_indicadores.to_csv('df_indicadores.csv', index=False)

# %% [markdown]
# ## Base final

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1348 entries, 0 to 1348
# Data columns (total 81 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  727 non-null    object
#  1   nome                           1348 non-null   object
#  2   IDADE_ALUNO_2020               727 non-null    object
#  3   anos_na_PM_em_2020             727 non-null    float64
#  4   fase_e_turma_em_2020           727 non-null    object
#  5   PONTO_VIRADA_2020              701 non-null    object
#  6   INDE_2020                      727 non-null    object
#  7   INDE_CONCEITO_2020             727 non-null    object
#  8   PEDRA_2020                     727 non-null    object
#  9   DESTAQUE_IEG_2020              727 non-null    object
#  10  DESTAQUE_IDA_2020              727 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       727 non-null    float64
#  13  IEG_2020                       727 non-null    float64
#  14  IPS_2020                       727 non-null    float64
#  15  IDA_2020                       727 non-null    float64
#  16  IPP_2020                       727 non-null    float64
#  17  IPV_2020                       727 non-null    float64
#  18  IAN_2020                       727 non-null    float64
#  19  fase_em_2021                   686 non-null    float64
#  20  TURMA_2021                     686 non-null    object
#  21  INSTITUICAO_ENSINO_ALUNO_2021  686 non-null    object
#  22  SINALIZADOR_INGRESSANTE_2021   686 non-null    object
#  23  PEDRA_2021                     686 non-null    object
#  24  INDE_2021                      686 non-null    object
#  25  IAA_2021                       686 non-null    float64
#  26  IEG_2021                       686 non-null    float64
#  27  IPS_2021                       686 non-null    float64
#  28  IDA_2021                       686 non-null    float64
#  29  IPP_2021                       686 non-null    float64
#  30  REC_EQUIPE_1_2021              686 non-null    object
#  31  REC_EQUIPE_2_2021              686 non-null    object
#  32  REC_EQUIPE_3_2021              686 non-null    object
#  33  REC_EQUIPE_4_2021              686 non-null    object
#  34  PONTO_VIRADA_2021              686 non-null    object
#  35  IPV_2021                       686 non-null    float64
#  36  IAN_2021                       686 non-null    float64
#  37  NIVEL_IDEAL_2021               686 non-null    object
#  38  DEFASAGEM_2021                 686 non-null    float64
#  39  fase_em_2022                   862 non-null    float64
#  40  TURMA_2022                     862 non-null    object
#  41  ANO_INGRESSO_2022              862 non-null    float64
#  42  BOLSISTA_2022                  862 non-null    object
#  43  INDE_2022                      862 non-null    float64
#  44  CG_2022                        862 non-null    float64
#  45  CF_2022                        862 non-null    float64
#  46  CT_2022                        862 non-null    float64
#  47  PEDRA_2022                     862 non-null    object
#  48  DESTAQUE_IEG_2022              862 non-null    object
#  49  DESTAQUE_IDA_2022              862 non-null    object
#  50  DESTAQUE_IPV_2022              862 non-null    object
#  51  IAA_2022                       862 non-null    float64
#  52  IEG_2022                       862 non-null    float64
#  53  IPS_2022                       862 non-null    float64
#  54  IDA_2022                       862 non-null    float64
#  55  NOTA_PORT_2022                 860 non-null    float64
#  56  NOTA_MAT_2022                  860 non-null    float64
#  57  NOTA_ING_2022                  285 non-null    float64
#  58  QTD_AVAL_2022                  862 non-null    float64
#  59  IPP_2022                       862 non-null    float64
#  60  REC_AVA_1_2022                 862 non-null    object
#  61  REC_AVA_2_2022                 862 non-null    object
#  62  REC_AVA_3_2022                 626 non-null    object
#  63  REC_AVA_4_2022                 285 non-null    object
#  64  INDICADO_BOLSA_2022            862 non-null    object
#  65  PONTO_VIRADA_2022              862 non-null    object
#  66  IPV_2022                       862 non-null    float64
#  67  IAN_2022                       862 non-null    float64
#  68  NIVEL_IDEAL_2022               862 non-null    object
#  69  fase_em_2020                   727 non-null    float64
#  70  aluno_em_2020                  1348 non-null   bool
#  71  aluno_em_2021                  1348 non-null   bool
#  72  aluno_em_2022                  1348 non-null   bool
#  73  aluno_em_2019                  1348 non-null   bool
#  74  aluno_em_2018                  1348 non-null   bool
#  75  aluno_em_2017                  1348 non-null   bool
#  76  aluno_em_2016                  1348 non-null   bool
#  77  ano_de_entrada                 1348 non-null   int64
#  78  ano_de_saida                   486 non-null    float64
#  79  aluno_no_momento               1348 non-null   bool
#  80  anos_matriculados              1348 non-null   int64
# dtypes: bool(8), float64(36), int64(2), object(35)
# memory usage: 789.8+ KB

# %%
# Colunas qu serão utiliados para análise


colunas_selecionadas = ['nome',
                        'aluno_no_momento',
                        'anos_matriculados',
                        'ano_de_entrada',
                        'ano_de_saida',
                        'aluno_em_2016',
                        'aluno_em_2017',
                        'aluno_em_2018',
                        'aluno_em_2019',
# Maior detalhamento após 2020
                        'aluno_em_2020',
                        'fase_em_2020',

#                        'IAN_2020',
#                        'IDA_2020',
#                        'IEG_2020',
#                        'IAA_2020',
#                        'IPS_2020',
#                        'IPP_2020',
#                        'IPV_2020',

                        'aluno_em_2021',
                        'fase_em_2021',
                        'aluno_em_2022',
                        'fase_em_2022'
                        #'',
                        ]

df_clean = df[colunas_selecionadas]

# %%
df_clean.head()
# Out:
#       nome  aluno_no_momento  anos_matriculados  ano_de_entrada  ano_de_saida  \
# 0  ALUNO-1             False                  2            2018        2021.0
# 1  ALUNO-2              True                  1            2022           NaN
# 2  ALUNO-3             False                  2            2018        2021.0
# 3  ALUNO-4              True                  2            2018           NaN
# 4  ALUNO-5              True                  3            2019           NaN
#
#    aluno_em_2016  aluno_em_2017  aluno_em_2018  aluno_em_2019  aluno_em_2020  \
# 0          False          False           True           True           True
# 1          False          False          False          False          False
# 2          False          False           True           True           True
# 3          False          False           True           True           True
# 4          False          False          False           True           True
#
#    fase_em_2020  aluno_em_2021  fase_em_2021  aluno_em_2022  fase_em_2022
# 0           2.0           True           2.0          False           NaN
# 1           NaN          False           NaN           True           0.0
# 2           3.0           True           3.0          False           NaN
# 3           1.0          False           NaN           True           2.0
# 4           2.0           True           2.0           True           2.0

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1348 entries, 0 to 1348
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nome               1348 non-null   object
#  1   aluno_no_momento   1348 non-null   bool
#  2   anos_matriculados  1348 non-null   int64
#  3   ano_de_entrada     1348 non-null   int64
#  4   ano_de_saida       486 non-null    float64
#  5   aluno_em_2016      1348 non-null   bool
#  6   aluno_em_2017      1348 non-null   bool
#  7   aluno_em_2018      1348 non-null   bool
#  8   aluno_em_2019      1348 non-null   bool
#  9   aluno_em_2020      1348 non-null   bool
#  10  fase_em_2020       727 non-null    float64
#  11  aluno_em_2021      1348 non-null   bool
#  12  fase_em_2021       686 non-null    float64
#  13  aluno_em_2022      1348 non-null   bool
#  14  fase_em_2022       862 non-null    float64
# dtypes: bool(8), float64(4), int64(2), object(1)
# memory usage: 94.8+ KB

# %%
df_clean.to_csv('df_clean.csv', index=False)
